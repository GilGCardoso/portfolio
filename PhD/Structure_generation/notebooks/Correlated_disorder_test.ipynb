# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
# Add parent directory to path so we can import our module
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from Correlated_disorder_generation import make_correlated_disorder

# Run the generation
make_correlated_disorder(
    N=1000,                # number of points
    mesh_precision=1000,    # mesh resolution
    iterations=100,         # number of iterations
    perodic_boundaries=True,
    show_iteration=True,
    show_boundaries=True,
    max_xy=np.array([1, 1]),
    save_to_csv = False
)

# Plot result
"""plt.figure(figsize=(6, 6))
plt.scatter(structure[:, 0], structure[:, 1], s=10, color='blue')
plt.axis('equal')
plt.title("Correlated Disorder Structure")
plt.show()"""
# Out:
# 2025-08-12 14:27:50,314 - INFO - 0.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:50,630 - INFO - 1.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:50,957 - INFO - 2.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:51,263 - INFO - 3.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:51,585 - INFO - 4.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:51,896 - INFO - 5.0 %
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2025-08-12 14:27:52,222 - INFO - 6.0 %
# ...
