# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# Add parent directory to path so we can import our module
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Import our classes
import Particules_position_identification as NP_id

raw_image = NP_id.fetch_file('.',"NanoP2710N2_liftoff_08112021_04.jpg")

bin_image = NP_id.binary_conversion(raw_image,0.1)
particles = NP_id.area_selection(bin_image, 5, 100)

# %%
print(raw_image)
# Out:
# [[0.19215686 0.24705882 0.31372549 ... 0.37647059 0.42745098 0.67843137]
#  [0.21568627 0.24705882 0.23921569 ... 0.43137255 0.76862745 0.72941176]
#  [0.21568627 0.27058824 0.23529412 ... 0.87058824 0.76862745 0.64313725]
#  ...
#  [1.         0.         0.         ... 0.         0.         1.        ]
#  [0.97647059 0.09019608 0.         ... 0.         0.09019608 0.97647059]
#  [0.98823529 0.94117647 1.         ... 1.         0.94117647 0.98823529]]
